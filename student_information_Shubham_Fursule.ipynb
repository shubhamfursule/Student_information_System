# %%
from IPython.core.display import display, HTML, Image
display(HTML("<style>.container { width:90% !important; }</style>"))
Image('https://www.python.org/images/python-logo.gif')
# Out:
# <style>.container { width:90% !important; }</style>

# %%
student_information={'rohit':{'Name': 'rohit', 'DOB': '1937-11-2', 'Address': 'mumbai', 'Class X percentage': 75.0, 'Class XII precentage': 85.0, 'Year': 2, 'Degrees': 'EE', 'GPA': 6.0},
                    'virat':{'Name': 'virat', 'DOB': '1998-1-23', 'Address': 'delhi', 'Class X percentage': 78.0, 'Class XII precentage': 86.0, 'Year': 3, 'Degrees': 'CS', 'GPA': 8.0},
                    'ronaldo':{'Name': 'ronaldo', 'DOB': '1991-7-2', 'Address': 'pune', 'Class X percentage': 65.0, 'Class XII precentage': 75.0, 'Year': 2, 'Degrees': 'BT', 'GPA': 7.0},
                    'amit':{'Name': 'amit', 'DOB': '1995-7-2', 'Address': 'goa', 'Class X percentage': 65.0, 'Class XII precentage': 75.0, 'Year': 1, 'Degrees': 'BT', 'GPA': 9.2},
                     'messi':{'Name': 'messi', 'DOB': '1991-7-2', 'Address': 'USA', 'Class X percentage': 75.0, 'Class XII precentage': 63.0, 'Year': 2, 'Degrees': 'CS', 'GPA': 6.2},
                     'rutuja':{'Name': 'rutuja', 'DOB': '1992-4-5', 'Address': 'Tirupati', 'Class X percentage': 55.0, 'Class XII precentage': 52.0, 'Year': 4, 'Degrees': 'CS', 'GPA': 5.2},
                      'vijaya':{'Name': 'vijaya', 'DOB': '1999-6-2', 'Address': 'mumbai', 'Class X percentage': 61.0, 'Class XII precentage': 67.0, 'Year': 3, 'Degrees': 'BT', 'GPA': 8.3},
                      'shubham':{'Name': 'shubham', 'DOB': '1992-9-5', 'Address': 'amravati', 'Class X percentage': 92.0, 'Class XII precentage': 85.0, 'Year': 3, 'Degrees': 'CS', 'GPA': 6.6},
                      'om':{'Name': 'om', 'DOB': '1981-7-26', 'Address': 'pune', 'Class X percentage': 62.0, 'Class XII precentage': 84.0, 'Year': 1, 'Degrees': 'CS', 'GPA': 5.9},
                      'sachin':{'Name': 'sachin', 'DOB': '1980-9-2', 'Address': 'USA', 'Class X percentage': 66.0, 'Class XII precentage': 77.0, 'Year': 2, 'Degrees': 'CS', 'GPA': 7.6},
                      'suresh':{'Name': 'suresh', 'DOB': '1991-9-22', 'Address': 'goa', 'Class X percentage': 55.0, 'Class XII precentage': 76.0, 'Year': 4, 'Degrees': 'BT', 'GPA': 4.2}}

# %%
                     
def enroll_student():
    student_detail={}
    list_degrees=['CS','EE','CE','CH','BT','MT','ME','EC','TT','PH','HR']
    while True :
        try:
            Name = input("Name of Student: ").lower()
            if " "in Name:
                Name1=""
                for n in Name.split(" "):
                    Name1+=n
                if Name1.isalpha():
                    student_detail.update({"Name":Name})
                    break
                else:
                    raise "error1"
            else:
                if Name.isalpha():
                    student_detail.update({"Name":Name})
                    break
                else:
                    raise "error1"
        except:
            print("Enter only in string! ")

    while True:
        try:
            DOB = input("Enter DOB in YYYY-MM-DD : ")
            DOB1=DOB.split('-')
            if len(DOB1[0])==4 and int(DOB1[0])>1900 and  int(DOB1[0])<=2020  and (int(DOB1[1])<=12 and 
                int(DOB1[1])>=1)  and (int(DOB1[2])<=31 and int(DOB1[2])>=1):
                student_detail.update({'DOB':DOB})
                break
            else:
                raise "Error"
        except:
            print("Enter in proper way :")
       
    Address=input("Enter the student Address: ")
    student_detail.update({"Address":Address})
    while True:                
        try:
            X_class=float(input("X Percentage : "))
            if X_class<=100 and X_class>=35:
                student_detail.update({"Class X percentage":X_class})
                break
            else:
                raise 'ValueError'
        except:
                print("!! Enter In proper manner !!")
               
    while True:
        try:
            XII_class=float(input("XII precentage: "))
            if XII_class<=100 and XII_class>=35:
                student_detail.update({"Class XII precentage":XII_class})
                break
            else:
                raise "Error"
        except:
                print("!! Enter in proper way !!")
                        
    while True:
        try:
            Year=int(input("Year in which student is currently studing: "))
            if Year<=5 and Year>=1:
                student_detail.update({"Year":Year})
                break
            else:
                raise "Error"
        except:
            print("!!Enter year in proper range [1-5]!! ")
                               
    while True:
        try:
            print('\n',*list_degrees)
            Degree =input("Degree for which a student has enrolled : ").upper()
            if Degree in list_degrees :
                student_detail.update({"Degrees":Degree})
                break
            else:
                raise "error"
        except:
                print("Degree not in given list:")

    while True:
        try:
            GPA =float(input("GPA till now : "))
            if GPA<=10 and GPA>=0:
                student_detail.update({"GPA":GPA})
                break
            else:
                raise "error"
        except:
                print("Enter GPA only in range of [0,10] :")
    student_information.update({Name: student_detail})

def update_detail():
    update_item=['Name','DOB','Address','Class X percentage','Class XII precentage','Year','Degrees','GPA']
    list_degrees1=['CS','EE','CE','CH','BT','MT','ME','EC','TT','PH','HR']
    Search_name=input("Enter the student name for update: ").lower()
    if Search_name in student_information:
        for item in range(len(update_item)):
            print(f"{item+1} : {update_item[item]}")
        try:    
            select=int(input("What do you want to update from above! "))
            if select>=(len(update_item)+1) and select<=0:
                raise "error"
            print(student_information[Search_name])
            if update_item[select-1]=='Name':
                
                while True:
                    try:
                        data_update=input(f"Enter update for {update_item[select-1]}: ")
                        if " "in data_update:
                            data_update1=""
                            for n in data_update.split(" "):
                                data_update1+=n
                            if data_update1.isalpha():
                                student_information[Search_name][update_item[select-1]]=data_update
                                student_information.update({data_update:student_information[Search_name]})
                                student_information.pop(Search_name)
                                break
                            else:
                                raise "error1"
                        else:
                            if data_update.isalpha():
                                student_information[Search_name][update_item[select-1]]=data_update
                                a=student_information[Search_name]
                                student_information.update({data_update:a})
                                student_information.pop(Search_name)
                                break
                            else:
                                raise "error1"
                    except:
                        print("Enter in proper type! ")
            elif update_item[select-1]=='DOB':
                while True:
                    try:
                        update_DOB = input("Enter New DOB in YYYY-MM-DD : ")
                        update_DOB1=update_DOB.split('-')
                        if len(update_DOB1[0])==4 and int(update_DOB1[0])>1900 and  int(update_DOB1[0])<=2020  and (int(update_DOB1[1])<=12 and 
                            int(update_DOB1[1])>=1)  and (int(update_DOB1[2])<=31 and int(update_DOB1[2])>=1):
                            student_information[Search_name][update_item[select-1]]=update_DOB
                            break
                        else:
                            raise "Error"
                    except:
                        print("Enter in proper way :")
            elif update_item[select-1]=='Address':
                update_address=input("Enter new address : ")
                student_information[Search_name][update_item[select-1]]=update_address
            elif update_item[select-1]=='Class X percentage':
                while True:                
                    try:
                        update_X=float(input("Update precentage for X class :"))
                        if update_X<=100:
                            student_information[Search_name][update_item[select-1]]=update_X
                            break
                        else:
                            raise 'ValueError'
                    except:
                        print("!! Enter In proper manner !!")
            elif update_item[select-1]=='Class XII precentage':
                while True:
                    try:
                        update_XII_class=float(input("Update XII precentage: "))
                        if update_XII_class<=100:
                            student_information[Search_name][update_item[select-1]]=update_XII_class
                            break
                        else:
                            raise "Error"
                    except:
                        print("!! Enter in proper way !!")
            elif update_item[select-1]=='Year':
                while True:
                    try:
                        update_Year=int(input("Update New Year  "))
                        if update_Year<=5 and update_Year>=1:
                            student_information[Search_name][update_item[select-1]]=update_Year
                            break
                        else:
                            raise "Error"
                    except:
                        print("!!Enter year in proper range [1-5]!! ")
            elif update_item[select-1]=='Degrees':
                while True:
                    try:
                        print('\n',*list_degrees1)
                        update_Degree =input(f"Update Degree for {Search_name}: ").upper()
                        if update_Degree in list_degrees1 :
                            student_information[Search_name][update_item[select-1]]=update_Degree
                            break
                        else:
                            raise "error"
                    except:
                        print("Degree not in given list:")
            elif update_item[select-1]=='GPA':
                while True:
                    try:
                        if student_information[Search_name]['GPA']>=5.0:
                            update_GPA =float(input("Update GPA till now : "))
                            if update_GPA<=10 and update_GPA>=0: 
                                print(f"{Search_name} promoted to next year !")
                                student_information[Search_name][update_item[select-1]]=update_GPA
                                break
                            
                            else:
                                raise "error"
                        else:
                            print(f"{Search_name} is not promoted in next year!")
                            break
                    except:
                        print("Enter GPA only in range of [0,10] :")
                                  
        except :
            print("Enter only interger from list !")
    else:
        print(f"'{Search_name}' is not present in database!")

def delete_student():
    while True:
        try:
            student_delete=input("Enter student name for delete information:").lower()
            if student_delete in student_information:
                del student_information[student_delete]
                print(f"{student_delete} is deleted from student informaion")
                break
            else:
                print(f"{student_delete} not present in list! ")
                break
                
        except:
            print("Enter only in string! ")   
            
def range_GPA(a,b):
    list_name=[]
    res = dict(sorted(student_information.items(),key=lambda x:x[1]['GPA']))
    for k in res.keys():
        if student_information[k]['GPA']>=a and student_information[k]['GPA']<=b:
            list_name.append(k)
    return list_name

print('Welcome to the information system.')
while True:
    print("-----------------------------------------------------------------------------")
    print("\n1. Enroll a new student\n2. Update student's information\n3. Delete a student information \n4. List names of all student\
    of a given year\n5. Given names of all student who have GPA in a given range[a,b]\n6. Find top-5 performing of each degree.\n7. exit")
    choose=int(input('Choose tasks to perform from 1 to 6 :'))
    if choose==1:
        print("Enrolling a  new student.Enter following detail: ")
        enroll_student()
        continue
    elif choose==2:
        print("update a student information ")
        update_detail()
        continue
    elif choose==3:
        print("Delete a student information ")
        delete_student()
        continue
    elif choose==4:
        while True:
            try:
                Year1=int(input("Enter Year for getting of list of student : "))
                if Year1>=1 and Year1<=5:
                    print("\n1.sorted (increasing) in the order of name \n2.sorted (increasing) in the order of GPA")

                    choose_sort=int(input("\nchoose above option: "))
                    if choose_sort==1:
                        res1=dict(sorted(student_information.items()))
                        for i in res1.keys():
                            if student_information[i]['Year']==Year1:       
                                print(i)
                        break
                    elif choose_sort==2:
                        res = dict(sorted(student_information.items(),key=lambda x:x[1]['GPA']))
                        for j in res.keys():
                            if student_information[j]['Year']==Year1:
                                print(j)
                        break

                    else:
                        print("Enter only two option :")
                        continue
                else:
                    raise 'error'
            except:
                print("Enter Year in range[1-5]")
        continue
    elif choose==5:
        while True:
            try:
                GPA=input("Enter name of student having GPA in range [a,b]:").split(',')
                if (float(GPA[0])>=1 and float(GPA[0])<=10) and (float(GPA[1])>=1 and float(GPA[1])<=10):
                    list1_gpa=range_GPA(float(GPA[0]),float(GPA[1]))  
                    print(f"Year student GPA in a range from {GPA[0]} to {GPA[1]} : ")
                    for item1 in range(len(list1_gpa)):
                        print(f"{item1+1}. {list1_gpa[item1]}")
                    break
                else:
                    raise 'error1'
            except:
                print("Enter GPA in range [1,10]")
        continue
    elif choose==6:
        list_degrees1=['CS','EE','CE','CH','BT','MT','ME','EC','TT','PH','HR']
        for item3 in list_degrees1:
            student_perf=[]
            print(f"\n{item3}\n")
            for item4 in student_information:
                if student_information[item4]['Degrees']==item3:
                    student_perf.append(student_information[item4])
            a=sorted(student_perf,key=lambda x:x['GPA'])
            y=0
            for k in reversed(a):
                if y==5:
                    break        
                print(f"{y+1}. {k['Name']}  {k['GPA']}")
                y+=1      
        continue
    else:
        break
# Out:
# Welcome to the information system.
# -----------------------------------------------------------------------------
#
# 1. Enroll a new student
# 2. Update student's information
# 3. Delete a student information
# 4. List names of all student    of a given year
# 5. Given names of all student who have GPA in a given range[a,b]
# 6. Find top-5 performing of each degree.
# 7. exit
# Choose tasks to perform from 1 to 6 :1
# Enrolling a  new student.Enter following detail:
# Name of Student: mayur
# Enter DOB in YYYY-MM-DD : 1994-6-15
# Enter the student Address: nashik
# X Percentage : 67
# XII precentage: 86
# Year in which student is currently studing: 3
#
#  CS EE CE CH BT MT ME EC TT PH HR
# Degree for which a student has enrolled : ee
# GPA till now : 7.8
# -----------------------------------------------------------------------------
#
# 1. Enroll a new student
# 2. Update student's information
# 3. Delete a student information
# 4. List names of all student    of a given year
# ...

# %% [markdown]
# ## OPEN documentation in juypter
